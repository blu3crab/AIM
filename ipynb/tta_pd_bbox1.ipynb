# %%
from google.colab import drive
import sys
drive.mount('/content/gdrive')
sys.path.append('/content/gdrive/MyDrive/AIM')
# !ls -l /content/gdrive/MyDrive/AIM/*.pd
import aim_util
# Out:
# Mounted at /content/gdrive
# ls: cannot access '/content/gdrive/MyDrive/AIM/*.pd': No such file or directory

# %%
# Model A
import numpy as np #this line is added to make the code runnable in colab
import pandas as pd

preds = [
    ('of', np.array([[1812.8906 ,  434.29688],
       [1972.2656 ,  434.29688],
       [1972.2656 ,  525.9375 ],
       [1812.8906 ,  525.9375 ]], dtype=np.float32)),
    ('america', np.array([[2039.0361 ,  440.46344],
       [2700.8264 ,  430.73114],
       [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),
    ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,
        544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),
    ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [ 621.7188,   4004.2969]], dtype=np.float32))]

# Transpose the prediction data and convert it to a list of lists
data = [[word] + list(prediction.reshape(-1)) for word, prediction in preds]

# Create the Pandas DataFrame
df = pd.DataFrame(data, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

# Display the Pandas DataFrame
df

# Show the column data types
df.dtypes
# Out:
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object

# %%
# Model B
import numpy as np
import pandas as pd

preds = [
    ('of', np.array([[1812.8906,  434.29688],
       [1972.2656,  434.29688],
       [1972.2656,  525.9375 ],
       [1812.8906,  525.9375 ]], dtype=np.float32)),
    ('america', np.array([[2039.0361 ,  440.46344],
       [2700.8264 ,  430.73114],
       [2702.342  ,  533.7752 ],
       [2040.5515 ,  543.5075 ]], dtype=np.float32)),
    ('states', np.array([[1221.82   ,  484.05478],
       [1766.906  ,  442.125  ],
       [1774.8046 ,  544.8047 ],
       [1229.7185 ,  586.73444]], dtype=np.float32)),
    ('united', np.array([[ 640.5678 ,  508.20175],
       [1172.9049 ,  472.71265],
       [1180.0449 ,  579.8147 ],
       [ 621.7188,   4004.2969]], dtype=np.float32))]

#Create empty list to store dataframe values
data_list = []

for word, coords in preds:
    # Unpack coordinates array
    upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y  = coords.flatten()
    data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

# Create the Pandas DataFrame
df = pd.DataFrame(data_list, columns=['word',  'upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

#Convert the columns to the required data type
df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']] = df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']].astype(np.float32)

# Display the Pandas DataFrame
display(df)

#Show the column data types
print(df.dtypes)
# Out:
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697     621.718811    4004.296875
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object

# %%
# Model A
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    # Create empty list to store dataframe values
    data_list = []

    for word, coords in predictions:
        # Unpack coordinates array
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y  = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    # Create the Pandas DataFrame
    df = pd.DataFrame(data_list, columns=['word',  'upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

    # Convert the columns to the required data type
    df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']] = df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']].astype(np.float32)

    return df

preds = [
    ('of', np.array([[1812.8906 ,  434.29688],       [1972.2656 ,  434.29688],       [1972.2656 ,  525.9375 ],       [1812.8906 ,  525.9375 ]], dtype=np.float32)),
    ('america', np.array([[2039.0361 ,  440.46344],       [2700.8264 ,  430.73114],       [2702.342  ,  533.7752 ],       [2040.5515 ,  543.5075 ]], dtype=np.float32)),
    ('states', np.array([[1221.82   ,  484.05478],       [1766.906  ,  442.125  ],        [1774.8046 ,  544.8047 ],       [1229.7185 ,  586.73444]], dtype=np.float32)),
    ('united', np.array([[ 640.5678 ,  508.20175],       [1172.9049 ,  472.71265],       [1180.0449 ,  579.8147 ],       [ 621.7188,   4004.2969]], dtype=np.float32))]

‍‍‍# Call the function to get the dataframe
df = preds_to_pd(preds)

# Display the Pandas DataFrame
display(df)

# Show the column data types
print(df.dtypes)
# Out:
#   File "<ipython-input-3-456079d1af8f>", line 28
#     ‍‍‍# Call the function to get the dataframe
#     ^
# SyntaxError: invalid non-printable character U+200D

# %%
# Model B
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    # Create empty list to store dataframe values
    data_list = []

    for word, coords in predictions:
        # Unpack coordinates array
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y  = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    # Create the Pandas DataFrame
    df = pd.DataFrame(data_list, columns=['word',  'upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

    # Convert the columns to the required data type
    df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']] = df[['upper_left_X', 'upper_left_Y',  'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']].astype(np.float32)

    return df

preds = [
    ('of', np.array([[1812.8906 ,  434.29688],       [1972.2656 ,  434.29688],       [1972.2656 ,  525.9375 ],       [1812.8906 ,  525.9375 ]], dtype=np.float32)),
    ('america', np.array([[2039.0361 ,  440.46344],       [2700.8264 ,  430.73114],       [2702.342  ,  533.7752 ],       [2040.5515 ,  543.5075 ]], dtype=np.float32)),
    ('states', np.array([[1221.82   ,  484.05478],       [1766.906  ,  442.125  ],        [1774.8046 ,  544.8047 ],       [1229.7185 ,  586.73444]], dtype=np.float32)),
    ('united', np.array([[ 640.5678 ,  508.20175],       [1172.9049 ,  472.71265],       [1180.0449 ,  579.8147 ],       [2621.7188, 4004.2969]], dtype=np.float32)) ]


df = preds_to_pd(preds)

# Display the Pandas DataFrame
display(df)

# Show the column data types
print(df.dtypes)
# Out:
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object

# %%
# Model A
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
   # Create empty list to store dataframe values
   data_list = []
   for word, coords in predictions:
       # Unpack coordinates array
       upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y  = coords.flatten()
       data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

   # Create the Pandas DataFrame
   df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

   # Convert the columns to the required data type
   df[['upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']] = df[['upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y']].astype(np.float32)

   return df

def write_pd(df, path):
   """Write the DataFrame to a specified CSV file path"""
   df.to_csv(path, index=False)

preds = [
   ('of', np.array([[1812.8906 ,  434.29688],       [1972.2656 ,  434.29688],       [1972.2656 ,  525.9375 ],       [1812.8906 ,  525.9375 ]], dtype=np.float32)), and so on...  ]


df = preds_to_pd(preds)

# Specify the path where you want to save the CSV file
preds_pd_path = 'predictions_df_A.csv'
write_pd(df, preds_pd_path)

print(f"Dataframe successfully written to: {preds_pd_path}")
# Out:
#   File "<ipython-input-7-cae735d11dd5>", line 26
#     ('of', np.array([[1812.8906 ,  434.29688],       [1972.2656 ,  434.29688],       [1972.2656 ,  525.9375 ],       [1812.8906 ,  525.9375 ]], dtype=np.float32)), and so on...  ]
#                                                                                                                                                                     ^
# SyntaxError: invalid syntax

# %%
# Model B
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    # Create empty list to store dataframe values
    data_list = []

    for word, coords in predictions:
        # Unpack coordinates array
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    # Create the Pandas DataFrame
    df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

    # Convert the columns to the required data type
    df = df.astype({col: np.float32 for col in df.columns[1:]})

    return df

def write_pd(df, path):
    """Write the DataFrame to a CSV file at the specified path"""
    df.to_csv(path, index=False)
    print(f"Dataframe successfully written to: {path}")

preds = [  ('of', np.array([[1812.8906 ,  434.29688], [1972.2656 ,  434.29688], [1972.2656 ,  525.9375 ], [1812.8906 ,  525.9375 ]], dtype=np.float32)),  ('america', np.array([[2039.0361 ,  440.46344], [2700.8264 ,  430.73114], [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),  ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,  544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),  ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [2621.7188, 4004.2969]], dtype=np.float32)) ]


df = preds_to_pd(preds)

# Display the Pandas DataFrame
display(df)

preds_pd_path = "preds_df_B.csv"
write_pd(df, preds_pd_path)  # Write the dataframe to a CSV file

 # Show the column data types
print(df.dtypes)
print(f"Dataframe successfully written to: {preds_pd_path}")
# Out:
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# Dataframe successfully written to: preds_df_B.csv
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object
# ...

# %%
# !ls -l
# Out:
# total 12
# drwx------ 5 root root 4096 May 17 13:56 gdrive
# -rw-r--r-- 1 root root  445 May 17 13:59 preds_df_B.csv
# drwxr-xr-x 1 root root 4096 May 15 18:06 sample_data

# %%
# Model A
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    # Create empty list to store dataframe values
    data_list = []

    for word, coords in predictions:
        # Unpack coordinates array
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    # Create the Pandas DataFrame
    df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

    # Convert the columns to the required data type
    df = df.astype({col: np.float32 for col in df.columns[1:]})

    return df

def write_pd(df, path):
    """Write the DataFrame to a CSV file at the specified path"""
    df.to_csv(path, index=False)
    print(f"Dataframe successfully written to: {path}")

def read_pd(path):
    """Read the CSV file into a Pandas dataframe"""
    return pd.read_csv(path)

preds = [  ('of', np.array([[1812.8906 ,  434.29688], [1972.2656 ,  434.29688], [1972.2656 ,  525.9375 ], [1812.8906 ,  525.9375 ]], dtype=np.float32)),   ('america', np.array([[2039.0361 ,  440.46344], [2700.8264 ,  430.73114], [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),   ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,  544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),   ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [2621.7188, 4004.2969]], dtype=np.float32)) ]


df = preds_to_pd(preds)

# Display the Pandas DataFrame
print(df)

preds_pd_path = "preds_df_B.csv"
write_pd(df, preds_pd_path)  # Write the dataframe to a CSV file

 # Show the column data types
print(df.dtypes)
print(f"Dataframe successfully written to: {preds_pd_path}")


# Read the CSV file back into a Pandas dataframe
df_read = read_pd(preds_pd_path)
print(df_read)
print(df_read.dtypes)

# Compare the two dataframes
result = df.equals(df_read)
print("Result of comparison:", result)  # This should print True if the dataframes are identical
# Out:
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# Dataframe successfully written to: preds_df_B.csv
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object
# ...

# %%
# Model B
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    # Create empty list to store dataframe values
    data_list = []

    for word, coords in predictions:
        # Unpack coordinates array
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    # Create the Pandas DataFrame
    df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])

    # Convert the columns to the required data type
    df = df.astype({col: np.float32 for col in df.columns[1:]})
    return df

def write_pd(df, path):
    """Write the DataFrame to a CSV file at the specified path"""
    df.to_csv(path, index=False)
    print(f"Dataframe successfully written to: {path}")

def read_pd(path):
    """Read the CSV file into a Pandas dataframe"""
    read_df = pd.read_csv(path)
    return read_df

preds = [  ('of', np.array([[1812.8906 ,  434.29688], [1972.2656 ,  434.29688], [1972.2656 ,  525.9375 ], [1812.8906 ,  525.9375 ]], dtype=np.float32)),  ('america', np.array([[2039.0361 ,  440.46344], [2700.8264 ,  430.73114], [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),  ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,  544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),  ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [2621.7188, 4004.2969]], dtype=np.float32)) ]


df = preds_to_pd(preds)

# Display the Pandas DataFrame
print(df)

preds_pd_path = "preds_df_B.csv"
write_pd(df, preds_pd_path)  # Write the dataframe to a CSV file

 # Read the CSV file back into a Pandas dataframe
read_df = read_pd(preds_pd_path)

# Show the column data types
print(df.dtypes)
print(f"Dataframe successfully read from: {preds_pd_path}")

# Compare the two dataframes
result = df.equals(read_df)
print("Result of comparison:", result)  # This should print True if the two dataframes are identical
# Out:
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# Dataframe successfully written to: preds_df_B.csv
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object
# ...

# %%
# Model A
import pickle
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    data_list = []

    for word, coords in predictions:
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])
    df = df.astype({col: np.float32 for col in df.columns[1:]})

    return df

def write_to_pickle(df, path):
    """Write the DataFrame to a Pickle file (*.pkl) at the specified path"""
    with open(path, 'wb') as f:
        pickle.dump(df, f)
        print(f"Dataframe successfully written to: {path}")

def read_from_pickle(path):
    """Read the Pickle file into a Pandas dataframe"""
    with open(path, 'rb') as f:
        return pickle.load(f)

preds = [  ('of', np.array([[1812.8906 ,  434.29688], [1972.2656 ,  434.29688], [1972.2656 ,  525.9375 ], [1812.8906 ,  525.9375 ]], dtype=np.float32)),   ('america', np.array([[2039.0361 ,  440.46344], [2700.8264 ,  430.73114], [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),   ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,  544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),   ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [2621.7188, 4004.2969]], dtype=np.float32))  ]

df = preds_to_pd(preds)
preds_pd_path = "preds_df.pkl"
write_to_pickle(df, preds_pd_path)

# Show the column data types
print(df.dtypes)

df_read = read_from_pickle(preds_pd_path)
print(df_read)
print(df_read.dtypes)

# Compare the two dataframes
result = df.equals(df_read)
print("Result of comparison:", result)
# Out:
# Dataframe successfully written to: preds_df.pkl
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# dtype: object
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# ...

# %%
# Model B
import pickle
import numpy as np
import pandas as pd

def preds_to_pd(predictions):
    data_list = []

    for word, coords in predictions:
        upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y = coords.flatten()
        data_list.append([word, upper_left_X, upper_left_Y, lower_left_X, lower_left_Y, lower_right_X, lower_right_Y, upper_right_X, upper_right_Y])

    df = pd.DataFrame(data_list, columns=['word', 'upper_left_X', 'upper_left_Y', 'lower_left_X', 'lower_left_Y', 'lower_right_X', 'lower_right_Y', 'upper_right_X', 'upper_right_Y'])
    df = df.astype({col: np.float32 for col in df.columns[1:]})

    return df

def write_to_pickle(df, path):
    """Write the DataFrame to a Pickle file (*.pkl) at the specified path"""
    with open(path, 'wb') as f:
        pickle.dump(df, f)
        print(f"Dataframe successfully written to: {path}")

def read_from_pickle(path):
    """Read the Pickle file into a Pandas dataframe"""
    with open(path, 'rb') as f:
        return pickle.load(f)

preds = [  ('of', np.array([[1812.8906 ,  434.29688], [1972.2656 ,  434.29688], [1972.2656 ,  525.9375 ], [1812.8906 ,  525.9375 ]], dtype=np.float32)),   ('america', np.array([[2039.0361 ,  440.46344], [2700.8264 ,  430.73114], [2702.342  ,  533.7752 ], [2040.5515 ,  543.5075 ]], dtype=np.float32)),   ('states', np.array([[1221.82   ,  484.05478], [1766.906  ,  442.125  ], [1774.8046 ,  544.8047 ], [1229.7185 ,  586.73444]], dtype=np.float32)),   ('united', np.array([[ 640.5678 ,  508.20175], [1172.9049 ,  472.71265], [1180.0449 ,  579.8147 ], [2621.7188, 4004.2969]], dtype=np.float32))  ]

df = preds_to_pd(preds)
preds_pd_path = "preds_df.pkl"
write_to_pickle(df, preds_pd_path)

df_read = read_from_pickle(preds_pd_path)

# Compare the two dataframes
result = df.equals(df_read)
print("Result of comparison:", result)

print(df_read)
print(df_read.dtypes)
# Out:
# Dataframe successfully written to: preds_df.pkl
# Result of comparison: True
#       word  upper_left_X  upper_left_Y  lower_left_X  lower_left_Y  \
# 0       of   1812.890625    434.296875   1972.265625    434.296875
# 1  america   2039.036133    440.463440   2700.826416    430.731140
# 2   states   1221.819946    484.054779   1766.906006    442.125000
# 3   united    640.567810    508.201752   1172.904907    472.712646
#
#    lower_right_X  lower_right_Y  upper_right_X  upper_right_Y
# 0    1972.265625     525.937500    1812.890625     525.937500
# 1    2702.342041     533.775208    2040.551514     543.507507
# 2    1774.804565     544.804688    1229.718506     586.734436
# 3    1180.044922     579.814697    2621.718750    4004.296875
# word              object
# upper_left_X     float32
# upper_left_Y     float32
# lower_left_X     float32
# lower_left_Y     float32
# lower_right_X    float32
# lower_right_Y    float32
# upper_right_X    float32
# upper_right_Y    float32
# ...
